# %%
import requests
import pandas as pd
import numpy as np

# %%
merged_gw = pd.read_csv('./data/2019-20/gws/merged_gw.csv')

# %%
merged_gw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22560 entries, 0 to 22559
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               22560 non-null  object
#  1   assists            22560 non-null  int64
#  2   bonus              22560 non-null  int64
#  3   bps                22560 non-null  int64
#  4   clean_sheets       22560 non-null  int64
#  5   creativity         22560 non-null  float64
#  6   element            22560 non-null  int64
#  7   fixture            22560 non-null  int64
#  8   goals_conceded     22560 non-null  int64
#  9   goals_scored       22560 non-null  int64
#  10  ict_index          22560 non-null  float64
#  11  influence          22560 non-null  float64
#  12  kickoff_time       22560 non-null  object
#  13  minutes            22560 non-null  int64
#  14  opponent_team      22560 non-null  int64
#  15  own_goals          22560 non-null  int64
# ...

# %%
merged_gw[merged_gw["GW"] == 47]
# Out:
#                       name  assists  bonus  bps  clean_sheets  creativity  \
# 21894   Aaron_Connolly_534        0      2   27             0         0.9
# 21895  Aaron_Cresswell_376        0      0    0             0         0.0
# 21896     Aaron_Lennon_430        0      0    0             0         0.0
# 21897       Aaron_Mooy_516        0      0    2             0        11.4
# 21898   Aaron_Ramsdale_494        0      0   18             0        10.0
# ...                    ...      ...    ...  ...           ...         ...
# 22555  Youri_Tielemans_448        0      0   11             0        37.4
# 22556     Yves_Bissouma_53        0      0   22             0         1.3
# 22557      Zech_Medley_636        0      0    0             0         0.0
# 22558   Çaglar_Söyüncü_164        0      0    0             0         0.0
# 22559      Ørjan_Nyland_27        0      0    0             0         0.0
#
#        element  fixture  goals_conceded  goals_scored  ...  team_h_score  \
# ...

# %%
merged_gw.columns
# Out:
# Index(['name', 'assists', 'bonus', 'bps', 'clean_sheets', 'creativity',
#        'element', 'fixture', 'goals_conceded', 'goals_scored', 'ict_index',
#        'influence', 'kickoff_time', 'minutes', 'opponent_team', 'own_goals',
#        'penalties_missed', 'penalties_saved', 'red_cards', 'round', 'saves',
#        'selected', 'team_a_score', 'team_h_score', 'threat', 'total_points',
#        'transfers_balance', 'transfers_in', 'transfers_out', 'value',
#        'was_home', 'yellow_cards', 'GW'],
#       dtype='object')

# %%
players_raw = pd.read_csv('./data/2019-20/players_raw.csv')

# %%
team = pd.read_csv('./data/2019-20/teams.csv')
